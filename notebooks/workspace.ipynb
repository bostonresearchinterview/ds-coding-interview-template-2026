# %% [markdown]
# # Data Science Coding Interview Workspace
#
# Use this notebook as a scratch workspace during the interview.
#
# The main Python package code lives under `src/interview/`.
# Tests live under `tests/`.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

print("Environment ready.")
