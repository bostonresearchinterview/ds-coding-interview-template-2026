# %% [markdown]
# # 2026 Data Science Interview Exercise
#
# This notebook contains the interview exercise prompt and is the primary workspace for your analysis.
#
# Use this notebook for your high-level workflow, results, explanations, tables, and visualizations.
#
# Reusable Python code that is cleaner to keep outside the notebook can be implemented in the package under `src/interview/`.
#
# Tests live under `tests/`.

# %%
import numpy as np

np.__version__
# Out:
# '2.4.4'
